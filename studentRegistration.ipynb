# %%
# Mounting Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Melihat Dataset secara garis besar
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/BIG-DATA/studentRegistration.csv')
df
# Out:
#       code_module code_presentation  id_student  date_registration  \
# 0             AAA             2013J       11391             -159.0
# 1             AAA             2013J       28400              -53.0
# 2             AAA             2013J       30268              -92.0
# 3             AAA             2013J       31604              -52.0
# 4             AAA             2013J       32885             -176.0
# ...           ...               ...         ...                ...
# 32588         GGG             2014J     2640965               -4.0
# 32589         GGG             2014J     2645731              -23.0
# 32590         GGG             2014J     2648187             -129.0
# 32591         GGG             2014J     2679821              -49.0
# 32592         GGG             2014J     2684003              -28.0
#
#        date_unregistration
# 0                      NaN
# 1                      NaN
# 2                     12.0
# 3                      NaN
# ...

# %%
# Melihat/showing percentage null values yang ada di dataset
print(f"Data Types:\n{df.dtypes}")
print(f"\nRows and Columns:\n{df.shape}")
print(f"\nColumn Names:\n{df.columns}")
print(f"\nNull Values %:\n{df.apply(lambda x: sum(x.isnull()) / len(df))}")
# Out:
# Data Types:
# code_module             object
# code_presentation       object
# id_student               int64
# date_registration      float64
# date_unregistration    float64
# dtype: object
#
# Rows and Columns:
# (32593, 5)
#
# Column Names:
# Index(['code_module', 'code_presentation', 'id_student', 'date_registration',
#        'date_unregistration'],
#       dtype='object')
#
# Null Values %:
# code_module            0.000000
# code_presentation      0.000000
# id_student             0.000000
# date_registration      0.001381
# date_unregistration    0.690977
# dtype: float64

# %%
# Mengisi Null Values yang ada di kolom 'date_unregistration' dan 'date_registration' dengan nilai "Uncategorized"
df["date_unregistration"].fillna("Uncategorized", inplace = True)
df["date_registration"].fillna("Uncategorized", inplace = True)

# %%
# Melihat/showing percentage null values yang ada di dataset
print(f"Data Types:\n{df.dtypes}")
print(f"\nRows and Columns:\n{df.shape}")
print(f"\nColumn Names:\n{df.columns}")
print(f"\nNull Values %:\n{df.apply(lambda x: sum(x.isnull()) / len(df))}")
# Out:
# Data Types:
# code_module            object
# code_presentation      object
# id_student              int64
# date_registration      object
# date_unregistration    object
# dtype: object
#
# Rows and Columns:
# (32593, 5)
#
# Column Names:
# Index(['code_module', 'code_presentation', 'id_student', 'date_registration',
#        'date_unregistration'],
#       dtype='object')
#
# Null Values %:
# code_module            0.0
# code_presentation      0.0
# id_student             0.0
# date_registration      0.0
# date_unregistration    0.0
# dtype: float64

# %%
df
# Out:
#       code_module code_presentation  id_student date_registration  \
# 0             AAA             2013J       11391            -159.0
# 1             AAA             2013J       28400             -53.0
# 2             AAA             2013J       30268             -92.0
# 3             AAA             2013J       31604             -52.0
# 4             AAA             2013J       32885            -176.0
# ...           ...               ...         ...               ...
# 32588         GGG             2014J     2640965              -4.0
# 32589         GGG             2014J     2645731             -23.0
# 32590         GGG             2014J     2648187            -129.0
# 32591         GGG             2014J     2679821             -49.0
# 32592         GGG             2014J     2684003             -28.0
#
#       date_unregistration
# 0           Uncategorized
# 1           Uncategorized
# 2                    12.0
# 3           Uncategorized
# 4           Uncategorized
# ...

# %%
# Visualisasi Bar Chart banyak data dari 'code_module'
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 4))
sns.countplot(x='code_module', data=df)
plt.xlabel('code_module')
plt.ylabel('Count')
plt.title('Count of code_module')
plt.xticks(rotation=45)
plt.show()

# %%
# Visualisasi Bar Chart banyak data dari 'code_presentation'
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 4))
sns.countplot(x='code_presentation', data=df)
plt.xlabel('code_presentation')
plt.ylabel('Count')
plt.title('Count of code_presentation')
plt.xticks(rotation=45)
plt.show()
