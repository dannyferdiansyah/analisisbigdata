# %%
# Mounting Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Melihat Dataset secara garis besar
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/BIG-DATA/vle.csv')
df
# Out:
#       id_site code_module code_presentation activity_type  week_from  week_to
# 0      546943         AAA             2013J      resource        NaN      NaN
# 1      546712         AAA             2013J     oucontent        NaN      NaN
# 2      546998         AAA             2013J      resource        NaN      NaN
# 3      546888         AAA             2013J           url        NaN      NaN
# 4      547035         AAA             2013J      resource        NaN      NaN
# ...       ...         ...               ...           ...        ...      ...
# 6359   897063         GGG             2014J      resource        NaN      NaN
# 6360   897109         GGG             2014J      resource        NaN      NaN
# 6361   896965         GGG             2014J     oucontent        NaN      NaN
# 6362   897060         GGG             2014J      resource        NaN      NaN
# 6363   897100         GGG             2014J      resource        NaN      NaN
#
# [6364 rows x 6 columns]

# %%
# Menghapus kolom yang tidak perlu karena null values yaitu 'week_form' dan 'week_to'
df = df.drop('week_from', axis=1)
df = df.drop('week_to', axis=1)

# %%
df
# Out:
#       id_site code_module code_presentation activity_type
# 0      546943         AAA             2013J      resource
# 1      546712         AAA             2013J     oucontent
# 2      546998         AAA             2013J      resource
# 3      546888         AAA             2013J           url
# 4      547035         AAA             2013J      resource
# ...       ...         ...               ...           ...
# 6359   897063         GGG             2014J      resource
# 6360   897109         GGG             2014J      resource
# 6361   896965         GGG             2014J     oucontent
# 6362   897060         GGG             2014J      resource
# 6363   897100         GGG             2014J      resource
#
# [6364 rows x 4 columns]

# %%
# Visualisasi Bar Chart banyak data dari 'activity_type'
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 4))
sns.countplot(x='activity_type', data=df)
plt.xlabel('activity_type')
plt.ylabel('Count')
plt.title('Count of activity_type')
plt.xticks(rotation=45)
plt.show()

# %%
# Visualisasi Bar Chart banyak data dari 'code_module'
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 4))
sns.countplot(x='code_module', data=df)
plt.xlabel('code_module')
plt.ylabel('Count')
plt.title('Count of code_module')
plt.xticks(rotation=45)
plt.show()

# %%
# Visualisasi Bar Chart banyak data dari 'code_presentation'
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 4))
sns.countplot(x='code_presentation', data=df)
plt.xlabel('code_presentation')
plt.ylabel('Count')
plt.title('Count of code_presentation')
plt.xticks(rotation=45)
plt.show()
